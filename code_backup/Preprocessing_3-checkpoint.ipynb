# %%
import pandas as pd
import numpy as np

# %%
# !pip install tmdbv3api

# %%
links_18_22 = ["https://en.wikipedia.org/wiki/List_of_American_films_of_2018", "https://en.wikipedia.org/wiki/List_of_American_films_of_2019","https://en.wikipedia.org/wiki/List_of_American_films_of_2020","https://en.wikipedia.org/wiki/List_of_American_films_of_2021"]

# %%
def links(links_18_22):
    df_list = []
    for link in links_18_22:
        df1 = pd.read_html(link, header=0)[2]
        df2 = pd.read_html(link, header=0)[3]
        df3 = pd.read_html(link, header=0)[4]
        df4 = pd.read_html(link, header=0)[5]
        df_list.append(df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True))
    df = pd.concat(df_list, ignore_index=True)
    return df

df = links(links_18_22)

df
# Out:
#        Opening  Opening.1                    Title  \
# 0      JANUARY        5.0  Insidious: The Last Key
# 1      JANUARY        5.0         The Strange Ones
# 2      JANUARY        5.0                 Stratton
# 3      JANUARY       10.0            Sweet Country
# 4      JANUARY       12.0             The Commuter
# ...        ...        ...                      ...
# 1151  DECEMBER       25.0   The Tragedy of Macbeth
# 1152  DECEMBER       25.0     A Journal for Jordan
# 1153  DECEMBER       25.0        American Underdog
# 1154  DECEMBER       26.0                  Memoria
# 1155  DECEMBER        NaN                      NaN
#
#                                      Production company  \
# 0     Universal Pictures / Blumhouse Productions / S...
# 1                                Vertical Entertainment
# 2                                     Momentum Pictures
# 3                                  Samuel Goldwyn Films
# 4         Lionsgate / StudioCanal / The Picture Company
# ...

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'cdbb1e4678647e469c56099008e432cf'
# tmdb.api_key = 'https://api.themoviedb.org/3/search/movie?api_key=cdbb1e4678647e469c56099008e432cf'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()

def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if len(result)>0:
        movie_id = result[0].id
        response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
        data_json = response.json()
        if data_json['genres']:
            genre_str = " " 
            for i in range(0,len(data_json['genres'])):
                genres.append(data_json['genres'][i]['name'])
            return genre_str.join(genres)
        else:
            return np.NaN
    else:
        return np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#        Opening  Opening.1                    Title  \
# 0      JANUARY        5.0  Insidious: The Last Key
# 1      JANUARY        5.0         The Strange Ones
# 2      JANUARY        5.0                 Stratton
# 3      JANUARY       10.0            Sweet Country
# 4      JANUARY       12.0             The Commuter
# ...        ...        ...                      ...
# 1151  DECEMBER       25.0   The Tragedy of Macbeth
# 1152  DECEMBER       25.0     A Journal for Jordan
# 1153  DECEMBER       25.0        American Underdog
# 1154  DECEMBER       26.0                  Memoria
# 1155  DECEMBER        NaN                      NaN
#
#                                      Production company  \
# 0     Universal Pictures / Blumhouse Productions / S...
# 1                                Vertical Entertainment
# 2                                     Momentum Pictures
# 3                                  Samuel Goldwyn Films
# 4         Lionsgate / StudioCanal / The Picture Company
# ...

# %%
df = df[['Title','Cast and crew','genres']]

# %%
df.dtypes
# Out:
# Title            object
# Cast and crew    object
# genres           object
# dtype: object

# %%
df['Cast and crew'][0].split(" (director)")[0]
# Out:
# 'Adam Robitel'

# %%
def get_director(x):
    try:
        if " (director)" in x:
            return x.split(" (director)")[0]
        elif " (directors)" in x:
            return x.split(" (directors)")[0]
        else:
            return x.split(" (director/screenplay)")[0]
    except:
        return np.NaN

# %%
df['director_name'] = df['Cast and crew'].map(lambda x: get_director(x))
# Out:
# <ipython-input-27-d27a6bf8d89f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['director_name'] = df['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor1(x):
    try:
        return ((x.split("screenplay); ")[-1]).split(", ")[0])
    except:
        return None

# %%
df['actor_1_name'] = df['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-33-603fbe2dd9d4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['actor_1_name'] = df['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    try:
        if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
            return np.NaN
        else:
            return ((x.split("screenplay); ")[-1]).split(", ")[1])
    except:
        return np.NaN

# %%
df['actor_2_name'] = df['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-37-5ea8f0c1ebc3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['actor_2_name'] = df['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    try:
        if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
            return np.NaN
        else:
            return ((x.split("screenplay); ")[-1]).split(", ")[2])
    except:
        return np.NaN

# %%
df['actor_3_name'] = df['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# <ipython-input-39-fc2fe3c8d5ef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['actor_3_name'] = df['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df = df.rename(columns={'Title':'movie_title'})

# %%
new_df = df.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df['actor_2_name'] = new_df['actor_2_name'].replace(np.nan, 'unknown')
new_df['actor_3_name'] = new_df['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df['movie_title'] = new_df['movie_title'].str.lower()

# %%
new_df['comb'] = new_df['actor_1_name'] + ' ' + new_df['actor_2_name'] + ' '+ new_df['actor_3_name'] + ' '+ new_df['director_name'] +' ' + new_df['genres']

# %%
new_df
# Out:
#                                           director_name  \
# 0                                          Adam Robitel
# 1                                      Lauren Wolkstein
# 2                                            Simon West
# 3                                      Warwick Thornton
# 4                                    Jaume Collet-Serra
# ...                                                 ...
# 1151                                          Joel Coen
# 1152                                  Denzel Washington
# 1153                                     Erwin brothers
# 1154  Apichatpong Weerasethakul (director/acreenplay...
# 1155                                                NaN
#
#                                            actor_1_name  \
# 0                                             Lin Shaye
# 1                                         Alex Pettyfer
# 2                                        Dominic Cooper
# 3                                           Bryan Brown
# ...

# %%
new_to_old_df = pd.read_csv('new_data.csv')

# %%
final_df = new_to_old_df.append(new_df,ignore_index=True)

# %%
final_df
# Out:
#                                           director_name  \
# 0                                         James Cameron
# 1                                        Gore Verbinski
# 2                                            Sam Mendes
# 3                                     Christopher Nolan
# 4                                           Doug Walker
# ...                                                 ...
# 6586                                          Joel Coen
# 6587                                  Denzel Washington
# 6588                                     Erwin brothers
# 6589  Apichatpong Weerasethakul (director/acreenplay...
# 6590                                                NaN
#
#                                            actor_1_name       actor_2_name  \
# 0                                           CCH Pounder   Joel David Moore
# 1                                           Johnny Depp      Orlando Bloom
# ...

# %%
final_df.isna().sum()
# Out:
# director_name    1
# actor_1_name     1
# actor_2_name     0
# actor_3_name     0
# genres           5
# movie_title      1
# comb             6
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.shape
# Out:
# (6585, 7)

# %%
final_df.to_csv('final_data.csv',index=False)
